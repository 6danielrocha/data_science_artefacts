# %% [markdown]
# # <font color='blue'>Cientista de Dados: Daniel Rocha de Araújo</font>
# # <font color='blue'>E-Gov BR Analytics</font>
#
# ## <font color='blue'>Projeto</font>
# ## <font color='blue'>Como Aumento do PIB e Gastos do Governo Impactam os Setores de Saúde e Educação</font>

# %% [markdown]
# ![title](imagens/gdp.jpg)

# %% [markdown]
# --------------------
# <a id='sumario'></a>
# Sumário<br/>
#
# [Pegunta 1](#p1).<br/>
#
# [Pegunta 2](#p2).<br/>
#
# [Pegunta 3](#p3).<br/>
#
# [Pegunta 4](#p4).<br/>
#
# [Pegunta 5](#p5).<br/>
#
# [Pegunta 6](#p6).<br/>
#
# [Pegunta 7](#p7).<br/>

# %% [markdown]
# -----------------
# ## Definição do Problema
#
# <p><strong>Principais objetivos:</strong></p>
# <ol>
# <li>Em que ano o pa&iacute;s teve um alto crescimento do PIB Per Capita?</li>
# <li>Qual ano teve as maiores despesas com sa&uacute;de?</li>
# <li>Qual ano teve os maiores gastos com educa&ccedil;&atilde;o?</li>
# <li>Como a receita do governo se correlaciona com a despesa do governo?</li>
# <li>Como a educa&ccedil;&atilde;o e a sa&uacute;de se correlacionam com o crescimento do PIB?</li>
# <li>Como os gastos do governo com educa&ccedil;&atilde;o e sa&uacute;de afetam o crescimento do PIB?</li>
# <li>Com base na an&aacute;lise quais s&atilde;o as recomenda&ccedil;&otilde;es aos governantes e gestores?</li>
# </ol>

# %% [markdown]
# ----------------------
# ## Fonte de Dados
#
# <p style="text-align: justify;">Para este trabalho usamos como fonte de dados a API fornecida pelo Banco Mundial no endere&ccedil;o abaixo:</p>
# <p style="text-align: justify;"><a href="http://api.worldbank.org/v2/en/country">http://api.worldbank.org/v2/en/country</a></p>
# <p style="text-align: justify;">A API permite extrair dados de diversos pa&iacute;ses simplesmente colocando o c&oacute;digo do pa&iacute;s ao final do endere&ccedil;o acima.</p>
# <p style="text-align: justify;">Extra&iacute;mos dados de um dos pa&iacute;ses no per&iacute;odo de 2003 a 2019 e ajustamos os nomes das colunas. Nosso objetivo aqui &eacute; estudar an&aacute;lise de dados e o processo a seguir no curso poder&aacute; ser aplicado a qualquer pa&iacute;s.</p>
# <p style="text-align: justify;">O reposit&oacute;rio de dados abertos do Banco Mundial oferece fonte valiosa de dados ao redor do mundo:</p>
# <p><a href="https://data.worldbank.org/">https://data.worldbank.org/</a></p>
# <p>&nbsp;</p>

# %% [markdown]
# ------------------
# ## Dicionário de Dados
#
# <table style="border-collapse: collapse; width: 100%;" border="1">
# <tbody>
# <tr>
# <td style="width: 50%;"><strong>Vari&aacute;vel</strong></td>
# <td style="width: 50%;"><strong>Descri&ccedil;&atilde;o</strong></td>
# </tr>
# <tr>
# <td style="width: 50%;">ano_coleta<br /><br /></td>
# <td style="width: 50%;">Ano da coleta dos dados</td>
# </tr>
# <tr>
# <td style="width: 50%;">despesas_educ_percent</td>
# <td style="width: 50%;">Despesas com educa&ccedil;&atilde;o secund&aacute;ria como uma porcentagem das<br />despesas do governo</td>
# </tr>
# <tr>
# <td style="width: 50%;">despesas_saude_per_capita</td>
# <td style="width: 50%;">Despesas atuais com sa&uacute;de per capita na taxa atual em d&oacute;lares dos EUA</td>
# </tr>
# <tr>
# <td style="width: 50%;">despesas_educ_total</td>
# <td style="width: 50%;">Despesas do governo com educa&ccedil;&atilde;o, total como uma porcentagem das<br />despesas do governo</td>
# </tr>
# <tr>
# <td style="width: 50%;">despesas_saude_%pib</td>
# <td style="width: 50%;">Despesas atuais com sa&uacute;de como uma porcentagem do PIB</td>
# </tr>
# <tr>
# <td style="width: 50%;">receita_trib_%pib</td>
# <td style="width: 50%;">Receita tribut&aacute;ria como porcentagem do PIB</td>
# </tr>
# <tr>
# <td style="width: 50%;">receita_excl_doa_%pib</td>
# <td style="width: 50%;">Receita excluindo doa&ccedil;&otilde;es como porcentagem do PIB</td>
# </tr>
# <tr>
# <td style="width: 50%;">ibrd_e_ida</td>
# <td style="width: 50%;">Empr&eacute;stimos do BIRD e cr&eacute;ditos da AID como DOD, US dolar atuais</td>
# </tr>
# <tr>
# <td style="width: 50%;">pop_cresc_anual%</td>
# <td style="width: 50%;">Crescimento populacional como porcentagem anual</td>
# </tr>
# <tr>
# <td style="width: 50%;">pib_cresc_per_capita_%pib</td>
# <td style="width: 50%;">Crescimento do PIB per capita como porcentagem anual</td>
# </tr>
# <tr>
# <td style="width: 50%;">pib_deflator</td>
# <td style="width: 50%;">Deflator do PIB, ano base varia por pa&iacute;s</td>
# </tr>
# <tr>
# <td style="width: 50%;">domestic_saude_despesas_%pib</td>
# <td style="width: 50%;">Despesas dom&eacute;sticas do governo geral com sa&uacute;de como uma<br />porcentagem do PIB</td>
# </tr>
# <tr>
# <td style="width: 50%;">pib_cresc_anual%</td>
# <td style="width: 50%;">Crescimento do PIB como uma porcentagem anual</td>
# </tr>
# <tr>
# <td style="width: 50%;">pib_cor_us </td>
# <td style="width: 50%;">PIB em US dolar correntes</td>
# </tr>
# <tr>
# <td style="width: 50%;">despesa_nac_bruta_%pib</td>
# <td style="width: 50%;">Despesa nacional bruta como uma porcentagem do PIB</td>
# </tr>
# <tr>
# <td style="width: 50%;">pib_moeda_local</td>
# <td style="width: 50%;">PIB em moeda local</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ------------------
# ## Base

# %% [markdown]
# “Per capita” é uma expressão em latim que significa “por cabeça”. Por isso que PIB per capita é o valor do PIB dividido pelo número de habitantes de uma região,

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %%
# suprimir notacao cientifica
pd.options.display.float_format = '{:.2f}'.format

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# numpy     : 1.19.5
# matplotlib: 3.1.1
# seaborn   : 0.11.1
# sklearn   : 0.23.2
# pandas    : 0.25.1

# %% [markdown]
# ### Base

# %% [markdown]
# “Per capita” é uma expressão em latim que significa “por cabeça”. Por isso que PIB per capita é o valor do PIB dividido pelo número de habitantes de uma região,

# %% [markdown]
# ## Carregando e Compreendendo os Dados

# %%
# Carrega o dataset
dados_egov = pd.read_excel('dados/dataset.xlsx')

# %%
# Shape
dados_egov.shape
# Out:
# (17, 16)

# %%
# Visualiza os dados
dados_egov.head()
# Out:
#    ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0        2003                  20.85                      25.44
# 1        2004                  23.41                      27.53
# 2        2005                    nan                      30.96
# 3        2006                  21.68                      40.94
# 4        2007                    nan                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17                nan
# 1                26.67                 5.34                nan
# 2                27.47                 5.31                nan
# 3                25.08                 5.87                nan
# 4                  nan                 6.00                nan
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                    nan 2741964000.00              2.71
# 1                    nan 2882726000.00              2.72
# ...

# %% [markdown]
# ## Análise Exploratória

# %%
# Tipos de dados
dados_egov.dtypes
# Out:
# ano_coleta                        int64
# despesas_educ_percent           float64
# despesas_saude_per_capita       float64
# despesas_educ_total             float64
# despesas_saude_%pib             float64
# receita_trib_%pib               float64
# receita_excl_doa_%pib           float64
# ibrd_e_ida                      float64
# pop_cresc_anual%                float64
# pib_cresc_per_capita_%pib       float64
# pib_deflator                    float64
# domestic_saude_despesas_%pib    float64
# pib_cresc_anual%                float64
# pib_cor_us$                     float64
# despesa_nac_bruta_%pib          float64
# pib_moeda_local                   int64
# dtype: object

# %%
# Resumo estatístico
dados_egov.describe().T.round(2)
# Out:
#                               count             mean              std  \
# ano_coleta                    17.00          2011.00             5.05
# despesas_educ_percent          8.00            34.78            10.63
# despesas_saude_per_capita     15.00            55.27            17.08
# despesas_educ_total           13.00            20.84             3.83
# despesas_saude_%pib           15.00             5.56             0.41
# receita_trib_%pib              5.00            16.01             0.68
# receita_excl_doa_%pib          5.00            21.03             0.94
# ibrd_e_ida                    16.00    3667158812.50     953267817.42
# pop_cresc_anual%              17.00             2.61             0.17
# pib_cresc_per_capita_%pib     17.00             2.54             1.80
# pib_deflator                  17.00           117.19            46.93
# domestic_saude_despesas_%pib  15.00             1.75             0.25
# ...

# %%
# Verificando valores ausentes
dados_egov.isnull().sum()
# Out:
# ano_coleta                       0
# despesas_educ_percent            9
# despesas_saude_per_capita        2
# despesas_educ_total              4
# despesas_saude_%pib              2
# receita_trib_%pib               12
# receita_excl_doa_%pib           12
# ibrd_e_ida                       1
# pop_cresc_anual%                 0
# pib_cresc_per_capita_%pib        0
# pib_deflator                     0
# domestic_saude_despesas_%pib     2
# pib_cresc_anual%                 0
# pib_cor_us$                      0
# despesa_nac_bruta_%pib           0
# pib_moeda_local                  0
# dtype: int64

# %% [markdown]
# ## Limpeza e Processamento dos Dados
#
# O que fazer nesta etapa?

# %% [markdown]
# ### Tratamento de Valores Ausentes com Backfilling e Interpolação

# %% [markdown]
# Recap of Pandas' fillna
# method='bfill': Bfill or backward-fill propagates the first observed non-null value backward until another non-null value is met. explicit value: It is also possible to set an exact value to replace all missings.

# %% [markdown]
# Pandas dataframe.interpolate() function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value.

# %%
# Limpando valores ausentes através de backfilling e interpolação
dados_egov['receita_trib_%pib'].fillna(method = 'bfill', inplace = True)
dados_egov['receita_excl_doa_%pib'].fillna(method = 'bfill', inplace = True)
dados_egov = dados_egov.interpolate()

# %%
# Verificando valores ausentes
dados_egov.isnull().sum()
# Out:
# ano_coleta                      0
# despesas_educ_percent           0
# despesas_saude_per_capita       0
# despesas_educ_total             0
# despesas_saude_%pib             0
# receita_trib_%pib               0
# receita_excl_doa_%pib           0
# ibrd_e_ida                      0
# pop_cresc_anual%                0
# pib_cresc_per_capita_%pib       0
# pib_deflator                    0
# domestic_saude_despesas_%pib    0
# pib_cresc_anual%                0
# pib_cor_us$                     0
# despesa_nac_bruta_%pib          0
# pib_moeda_local                 0
# dtype: int64

# %%
# Shape
dados_egov.shape
# Out:
# (17, 16)

# %%
# Vamos remover a coluna gdp em US$ uma vez que já o temos na moeda local.
dados_egov = dados_egov.drop(columns = ['pib_cor_us$'])

# %%
# Shape
dados_egov.shape
# Out:
# (17, 15)

# %%
# Arrendodamos os valores das colunas decimais para 4 casas decimais
dados_egov = dados_egov.round(4)

# %%
# Visualiza os dados
dados_egov.head()
# Out:
#    ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0        2003                  20.85                      25.44
# 1        2004                  23.41                      27.53
# 2        2005                  22.54                      30.96
# 3        2006                  21.68                      40.94
# 4        2007                  25.85                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17              16.88
# 1                26.67                 5.34              16.88
# 2                27.47                 5.31              16.88
# 3                25.08                 5.87              16.88
# 4                23.95                 6.00              16.88
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                  21.74 2741964000.00              2.71
# 1                  21.74 2882726000.00              2.72
# ...

# %%
# Salvamos o dataset limpo
dados_egov.to_csv('dados/dataset_limpo.csv', index = False)

# %% [markdown]
# ## Análise de Dados

# %%
# Carregando o dataset limpo
df = pd.read_csv('dados/dataset_limpo.csv')

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p1'></a>
#
# ## <font color = "red">1- Em Que Ano o País Teve um Alto Crescimento do PIB Per Capita?</font>

# %%
# Visualiza os dados
df.head()
# Out:
#    ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0        2003                  20.85                      25.44
# 1        2004                  23.41                      27.53
# 2        2005                  22.54                      30.96
# 3        2006                  21.68                      40.94
# 4        2007                  25.85                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17              16.88
# 1                26.67                 5.34              16.88
# 2                27.47                 5.31              16.88
# 3                25.08                 5.87              16.88
# 4                23.95                 6.00              16.88
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                  21.74 2741964000.00              2.71
# 1                  21.74 2882726000.00              2.72
# ...

# %%
# Resumo estatístico
df['pib_cresc_per_capita_%pib'].describe().T.round(2)
# Out:
# count   17.00
# mean     2.54
# std      1.80
# min     -2.50
# 25%      2.28
# 50%      3.04
# 75%      3.35
# max      5.49
# Name: pib_cresc_per_capita_%pib, dtype: float64

# %%
df['ano_coleta'] = df.ano_coleta.astype('category')

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="pib_cresc_per_capita_%pib", y="ano_coleta", data=df)
ax.set(xlabel="Crescimento do PIB em %", ylabel = "Ano")
plt.show()

# %%
df.loc[df['pib_cresc_per_capita_%pib'].idxmax()]
# Out:
# ano_coleta                               2010
# despesas_educ_percent                   38.38
# despesas_saude_per_capita               59.17
# despesas_educ_total                     20.56
# despesas_saude_%pib                      6.12
# receita_trib_%pib                       16.88
# receita_excl_doa_%pib                   21.74
# ibrd_e_ida                      3237614000.00
# pop_cresc_anual%                         2.72
# pib_cresc_per_capita_%pib                5.49
# pib_deflator                           102.09
# domestic_saude_despesas_%pib             1.77
# pib_cresc_anual%                         8.41
# despesa_nac_bruta_%pib                 112.16
# pib_moeda_local                 3169335000000
# Name: 7, dtype: object

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p2'></a>
#
# ## <font color = "red">2- Qual Ano Teve as Maiores Despesas com Saúde?</font>

# %%
# Visualiza os dados
df.head()
# Out:
#   ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0       2003                  20.85                      25.44
# 1       2004                  23.41                      27.53
# 2       2005                  22.54                      30.96
# 3       2006                  21.68                      40.94
# 4       2007                  25.85                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17              16.88
# 1                26.67                 5.34              16.88
# 2                27.47                 5.31              16.88
# 3                25.08                 5.87              16.88
# 4                23.95                 6.00              16.88
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                  21.74 2741964000.00              2.71
# 1                  21.74 2882726000.00              2.72
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="despesas_saude_%pib", y="ano_coleta", data=df)
ax.set(xlabel="Despesa com Saúde (% PIB)", ylabel = "Ano")
plt.show()

# %%
df.loc[df['despesas_saude_%pib'].idxmax()]
# Out:
# ano_coleta                               2010
# despesas_educ_percent                   38.38
# despesas_saude_per_capita               59.17
# despesas_educ_total                     20.56
# despesas_saude_%pib                      6.12
# receita_trib_%pib                       16.88
# receita_excl_doa_%pib                   21.74
# ibrd_e_ida                      3237614000.00
# pop_cresc_anual%                         2.72
# pib_cresc_per_capita_%pib                5.49
# pib_deflator                           102.09
# domestic_saude_despesas_%pib             1.77
# pib_cresc_anual%                         8.41
# despesa_nac_bruta_%pib                 112.16
# pib_moeda_local                 3169335000000
# Name: 7, dtype: object

# %% [raw]
# O ano em que o PIB mais cresceu foi 2010 - constatamos isso na pergunta 1
# Note que foi tambem o ano em que a despesa com saude em relação ao PIB mais cresceu
# Faz todo sentido uma vez que os gastos com saúde são definidos em relação ao PIB por lei

# %% [markdown]
# ## Lab

# %%
temp = df.copy()

# %%
temp.head()
# Out:
#   ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0       2003                20.8507                    25.4379
# 1       2004                23.4095                    27.5270
# 2       2005                22.5437                    30.9610
# 3       2006                21.6778                    40.9383
# 4       2007                25.8529                    50.3219
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0              24.9801               5.1691             16.877
# 1              26.6682               5.3449             16.877
# 2              27.4693               5.3144             16.877
# 3              25.0814               5.8734             16.877
# 4              23.9500               5.9971             16.877
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                21.7389  2.741964e+09            2.7096
# 1                21.7389  2.882726e+09            2.7208
# ...

# %%
# calcula gasto nacional bruto na moeda local
temp['gasto_nac_bruto'] = (temp['despesa_nac_bruta_%pib'] / 100) * temp['pib_moeda_local']
# calcula gasto com a saude na moeda local
temp['gastos_saude'] = (temp['domestic_saude_despesas_%pib'] / 100) * temp['gasto_nac_bruto']

# %%
# auxiliares
temp['saldo'] = temp['pib_moeda_local'] - temp['gasto_nac_bruto'] 
temp['saude_perc'] = temp['gastos_saude'] / temp['gasto_nac_bruto']

# %%
temp[["ano_coleta","gasto_nac_bruto", "pib_moeda_local","saldo", "saude_perc"]]
# Out:
#    ano_coleta   gasto_nac_bruto  pib_moeda_local             saldo  saude_perc
# 0        2003  1264569454932.00    1131782000000  -132787454932.00        0.01
# 1        2004  1406186370288.00    1274329000000  -131857370288.00        0.01
# 2        2005  1563375207425.00    1415725000000  -147650207425.00        0.01
# 3        2006  2033579665084.00    1862041000000  -171538665084.00        0.01
# 4        2007  2365221058137.00    2151349000000  -213872058137.00        0.02
# 5        2008  2746617225294.00    2483058000000  -263559225294.00        0.02
# 6        2009  3172920484992.00    2863688000000  -309232484992.00        0.02
# 7        2010  3554875094745.00    3169335000000  -385540094745.00        0.02
# 8        2011  4267040522976.00    3725918000000  -541122522976.00        0.02
# 9        2012  4860804137554.20    4261370003300  -599434134254.20        0.02
# 10       2013  5456416951720.00    4745090000000  -711326951720.00        0.02
# ...

# %%
# calcula gasto nacional bruto na moeda local
df['gasto_nac_bruto'] = (df['despesa_nac_bruta_%pib'] / 100) * df['pib_moeda_local']
# calcula gasto com a saude na moeda local
df['gastos_saude'] = (df['domestic_saude_despesas_%pib'] / 100) * df['gasto_nac_bruto']

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="gastos_saude", y="ano_coleta", data=df)
ax.set(xlabel="Despesa com Saúde", ylabel = "Ano")
plt.show()

# %%
df.loc[df['gastos_saude'].idxmax()]
# Out:
# ano_coleta                                  2019
# despesas_educ_percent                      41.76
# despesas_saude_per_capita                  76.61
# despesas_educ_total                        19.10
# despesas_saude_%pib                         4.80
# receita_trib_%pib                          15.09
# receita_excl_doa_%pib                      19.62
# ibrd_e_ida                         5801797000.00
# pop_cresc_anual%                            2.27
# pib_cresc_per_capita_%pib                   3.00
# pib_deflator                              192.90
# domestic_saude_despesas_%pib                2.05
# pib_cresc_anual%                            5.37
# despesa_nac_bruta_%pib                    112.95
# pib_moeda_local                    9740360000000
# gasto_nac_bruto                11001785321800.00
# gastos_saude                     225822645515.27
# Name: 16, dtype: object

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p3'></a>
#
# ## <font color = "red">3- Qual Ano Teve os Maiores Gastos com Educação?</font>

# %%
# Visualiza os dados
df.head()
# Out:
#   ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0       2003                  20.85                      25.44
# 1       2004                  23.41                      27.53
# 2       2005                  22.54                      30.96
# 3       2006                  21.68                      40.94
# 4       2007                  25.85                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17              16.88
# 1                26.67                 5.34              16.88
# 2                27.47                 5.31              16.88
# 3                25.08                 5.87              16.88
# 4                23.95                 6.00              16.88
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                  21.74 2741964000.00              2.71
# 1                  21.74 2882726000.00              2.72
# ...

# %%
# calcula gasto nacional bruto na moeda local
# df['gasto_nac_bruto'] = (df['despesa_nac_bruta_%pib'] / 100) * df['pib_moeda_local']
# calcula gasto com a saude na moeda local
df['gastos_educacao'] = (df['despesas_educ_total'] / 100) * df['gasto_nac_bruto']

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_theme(style="whitegrid")
ax = sns.barplot(x="gastos_educacao", y="ano_coleta", data=df)
ax.set(xlabel="Despesa com Educação", ylabel = "Ano")
plt.show()

# %%
df.loc[df['gastos_educacao'].idxmax()]
# Out:
# ano_coleta                                  2019
# despesas_educ_percent                      41.76
# despesas_saude_per_capita                  76.61
# despesas_educ_total                        19.10
# despesas_saude_%pib                         4.80
# receita_trib_%pib                          15.09
# receita_excl_doa_%pib                      19.62
# ibrd_e_ida                         5801797000.00
# pop_cresc_anual%                            2.27
# pib_cresc_per_capita_%pib                   3.00
# pib_deflator                              192.90
# domestic_saude_despesas_%pib                2.05
# pib_cresc_anual%                            5.37
# despesa_nac_bruta_%pib                    112.95
# pib_moeda_local                    9740360000000
# gasto_nac_bruto                11001785321800.00
# gastos_saude                     225822645515.27
# gastos_educacao                 2101781067876.67
# Name: 16, dtype: object

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p4'></a>
#
# ## <font color = "red">4- Como a Receita do Governo se Correlaciona com a Despesa do Governo?</font>

# %%
# Visualiza os dados
df.head()
# Out:
#   ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0       2003                  20.85                      25.44
# 1       2004                  23.41                      27.53
# 2       2005                  22.54                      30.96
# 3       2006                  21.68                      40.94
# 4       2007                  25.85                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17              16.88
# 1                26.67                 5.34              16.88
# 2                27.47                 5.31              16.88
# 3                25.08                 5.87              16.88
# 4                23.95                 6.00              16.88
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                  21.74 2741964000.00              2.71
# 1                  21.74 2882726000.00              2.72
# ...

# %%
# Compute the correlation matrix
corr = df.corr(method='pearson')

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(230, 20, as_cmap=True)
cmap = sns.diverging_palette(30, 600, s=90, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Correlação não implica causalidade

# coloqui aqui suas inferencias

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p5'></a>
#
# ## <font color = "red">5- Como a Educação e a Saúde se Correlacionam com o Crescimento do PIB?</font>

# %%
# Compute the correlation matrix
corr = df[["despesa_nac_bruta_%pib",
           "receita_trib_%pib",
           "ibrd_e_ida",
           "despesas_educ_total",
           "despesas_saude_%pib",
           "pop_cresc_anual%", 
           "pib_cresc_per_capita_%pib",
           "pib_cresc_anual%", 
           "pib_moeda_local"]].corr(method='pearson')

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
# cmap = sns.diverging_palette(230, 20, as_cmap=True)
cmap = sns.diverging_palette(30, 600, s=90, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Correlação não implica causalidade

# correlacao levemente negativa entre
# despesas_educ_total. despesas_saude_%pib  
# e
# pop_cresc_anual%, pib_cresc_per_capita_%pib 

# o que isso significa: 
# neste pais (em especial) a educação é despesa e não investimento
# investir em educação sem um planejamento, ambiente fertil a inovação e ao empreendedorismo
# não significa melhorias no pib
# considerando que o pib melhora com a entrada de dolares (exportações de produto ou serviços)

# a saude aqui - tambem tem natureza de despesa
# neste caso recomendaria - desonerar o sistema publico de saúde
# com programas de medicina preventiva, 
# e com o custeio parcial por parte da população

# de modo geral - sinalizam que os impostos não sao bem aplicados

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p6'></a>
# ## <font color = "red">6- Como os Gastos do Governo com Educação e Saúde Afetam o Crescimento do PIB?</font>

# %%
# Visualiza os dados
df.head()
# Out:
#   ano_coleta  despesas_educ_percent  despesas_saude_per_capita  \
# 0       2003                  20.85                      25.44
# 1       2004                  23.41                      27.53
# 2       2005                  22.54                      30.96
# 3       2006                  21.68                      40.94
# 4       2007                  25.85                      50.32
#
#    despesas_educ_total  despesas_saude_%pib  receita_trib_%pib  \
# 0                24.98                 5.17              16.88
# 1                26.67                 5.34              16.88
# 2                27.47                 5.31              16.88
# 3                25.08                 5.87              16.88
# 4                23.95                 6.00              16.88
#
#    receita_excl_doa_%pib    ibrd_e_ida  pop_cresc_anual%  \
# 0                  21.74 2741964000.00              2.71
# 1                  21.74 2882726000.00              2.72
# ...

# %%
df['gastos_saude_educacao'] = df['gastos_saude'] + df['gastos_educacao']

# %%
df.plot(x="gastos_saude_educacao",y="pib_cresc_anual%")
plt.xlabel("Gastos com saúde e educação")
plt.ylabel("Crescimento do PIB %")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from sklearn.datasets import load_boston 
from sklearn.linear_model import LinearRegression

X = df[["gastos_saude_educacao"]]
y = df['pib_cresc_anual%']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=10)

# %%
regr = LinearRegression()
regr.fit(X_train, y_train)
r2_train = regr.score(X_train, y_train)
r2_test = regr.score(X_test, y_test)
print('R2 no set de treino: %.2f' % r2_train)
print('R2 no set de teste: %.2f' % r2_test)
# Out:
# R2 no set de treino: 0.02
# R2 no set de teste: -0.42

# %%
regr.coef_
# Out:
# array([4.60594666e-13])

# %% [markdown]
# Os resultados sugerem que os gastos do governo com educação e saúde afetam positivamente o crescimento do PIB. muito muito pouco
#
# Um aumento unitário nas despesas do governo leva a um aumento unitário de 4.60594666e-13 no crescimento do PIB.

# %% [markdown]
# ----------------------
# [Sumário](#sumario).<br/>
# <a id='p7'></a>
#
# ## <font color = "red">7- Com Base na Análise Quais São as Recomendações aos Governantes e Gestores?</font>

# %%
# Criar um ambiente favorável a livre iniciativa, ao empreendedorismo 
# estimulando a geração de serviços e produtos
# reduzir a burocracia
# reduzir a carga tributária - em contra partida 
# compartilhar com a sociedade parte dos gastos em saude educação
# cada cidadão precisa ser responsavel por suas escolhas - em termo de educação 
# e o sistema de saúde precisa

# %% [markdown]
# # Fim
